# %%
# %load_ext autoreload
# %autoreload
from IPython.core.debugger import Tracer

import numpy as np
from keras.models import load_model
import matplotlib.pyplot as plt
from skimage.util import pad

# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
print('-'*30)
print('Loading and preprocessing training and validation data...')
print('-'*30)

path = 'data/'

imgs_train = np.load(path+'parts_train.npy')
imgs_mask_train = np.load(path+'parts_train_labels.npy')
imgs_validation = np.load(path+'parts_validation.npy')
imgs_mask_validation = np.load(path+'parts_validation_labels.npy')
# Out:
# ------------------------------
# Loading and preprocessing training and validation data...
# ------------------------------

# %%
imgs_train.shape
# Out:
# (1500, 256, 256, 3)

# %%
pad(imgs_train[0], ((3,3),(3,3),(0,0)), mode='constant').shape
# Out:
# (262, 262, 9)

# %%
plt.imshow(imgs_train[4])
plt.show()

# %%
plt.imshow(imgs_mask_train[4])
plt.show()
