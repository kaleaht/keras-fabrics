# %%
# %matplotlib inline
import pandas as pd

df = pd.read_csv("unet.csv", sep=",")

df.plot(y=['val_acc','acc'],figsize=(18,10))
df.plot(y=['val_loss','loss'],figsize=(18,10))
# Out:
# /u/07/akalervo/unix/.conda/envs/keras/lib/python3.6/site-packages/pandas/plotting/_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label
